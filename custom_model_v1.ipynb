# %% [markdown]
# ## Project: Named Entity Recognition model <br>
# Version: 0.1 <br>
# Author: Lakshitha Wisumperuma

# %% [markdown]
# ### Requirments <br>
# Install the dependancies using requirements.txt <br>
# Important:
# 1. Spacy should be version 2.3.5

# %%
# !pip3 install -r requirements.txt

# %% [markdown]
# ### Load Packages

# %%
from __future__ import unicode_literals, print_function
import pickle
import random
from pathlib import Path
import plac
import spacy
from spacy.util import minibatch, compounding

print(spacy.__version__)
# Out:
# 2.3.5

# %% [markdown]
# Following is optional, train using GPU <br>
# Requirments: <br>
#     1. GPU install <br>
#     2. CUDA installed

# %%
# !nvcc --version
spacy.require_gpu()
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243
# True

# %% [markdown]
# ### Entity labels

# %%
LABEL = ['I-geo', 'B-geo', 'I-art', 'B-art', 'B-tim', 'B-nat', 'B-eve', 'O', 'I-per', 'I-tim', 'I-nat', 'I-eve', 'B-per', 'I-org', 'B-gpe', 'B-org', 'I-gpe']

"""
geo = Geographical Entity
org = Organization
per = Person
gpe = Geopolitical Entity
tim = Time indicator
art = Artifact
eve = Event
nat = Natural Phenomenon
"""
# Out:
# '\ngeo = Geographical Entity\norg = Organization\nper = Person\ngpe = Geopolitical Entity\ntim = Time indicator\nart = Artifact\neve = Event\nnat = Natural Phenomenon\n'

# %% [markdown]
# ### Loading training data

# %%
with open ('spacy_dataset', 'rb') as fp:
    TRAIN_DATA = pickle.load(fp)

# %% [markdown]
# ### Model training fuction

# %%
def train_model(model, new_model_name, output_dir, n_iter):
    if model is not None:
        nlp = spacy.load(model)
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank('en')
        print("Created blank 'en' model")
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner)
    else:
        ner = nlp.get_pipe('ner')

    for i in LABEL:
        ner.add_label(i)

    if model is None:
        optimizer = nlp.begin_training()
    else:
        optimizer = nlp.entity.create_optimizer()

    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            batches = minibatch(TRAIN_DATA, size=compounding(4., 32., 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(texts, annotations, sgd=optimizer, drop=0.35,
                           losses=losses)
            print('Losses', losses)

    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.meta['name'] = new_model_name
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

# %% [markdown]
# ### Traning the Model

# %%
train_model("en_core_web_sm", 'new_model_v2', 'final/', 100)
# Out:
# Loaded model 'en_core_web_sm'
# Losses {'ner': 542846.9937061241}
# Losses {'ner': 531319.1385076634}
# Losses {'ner': 527744.917006569}
# Losses {'ner': 524900.4176091421}
# Losses {'ner': 525904.7823297309}
# Losses {'ner': 524448.7311715771}
# Losses {'ner': 523816.8188313992}
# Losses {'ner': 523186.12224400166}
# Losses {'ner': 522327.68912530446}
# Losses {'ner': 521809.3583123947}
# Losses {'ner': 524359.8282843948}
# Losses {'ner': 522506.66997830383}
# Losses {'ner': 523422.0864084009}
# Losses {'ner': 521380.46632373077}
# Losses {'ner': 519699.3646395472}
# Losses {'ner': 520189.2869832292}
# Losses {'ner': 521134.4424651233}
# Losses {'ner': 519937.94597516075}
# Losses {'ner': 521019.4313840747}
# Losses {'ner': 520372.42350722663}
# Losses {'ner': 522172.22954303224}
# Losses {'ner': 521409.2417482352}
# Losses {'ner': 518247.3741325028}
# Losses {'ner': 519127.6138641173}
# Losses {'ner': 520724.25288296887}
# Losses {'ner': 520943.07210891915}
# Losses {'ner': 519780.2917672277}
# Losses {'ner': 519182.7035299925}
# Losses {'ner': 519544.9632051736}
# Losses {'ner': 519232.5803170911}
# Losses {'ner': 520625.7113216369}
# Losses {'ner': 519855.0049705985}
# Losses {'ner': 518100.9368217525}
# Losses {'ner': 518480.2651222057}
# Losses {'ner': 519271.62544169836}
# Losses {'ner': 520704.8616786484}
# Losses {'ner': 518270.6950423136}
# Losses {'ner': 520451.5511437968}
# Losses {'ner': 520240.0507907298}
# Losses {'ner': 521033.4364282029}
# Losses {'ner': 519693.5889124989}
# Losses {'ner': 521795.095578881}
# Losses {'ner': 519777.12662050524}
# Losses {'ner': 519474.15499269107}
# Losses {'ner': 519489.79362778127}
# Losses {'ner': 520233.3604588127}
# Losses {'ner': 520017.04417450394}
# Losses {'ner': 519915.443693691}
# Losses {'ner': 519803.74741431803}
# Losses {'ner': 519955.15687033325}
# Losses {'ner': 520020.95077730576}
# Losses {'ner': 518885.07583903207}
# Losses {'ner': 519025.21000487695}
# Losses {'ner': 518870.2102153889}
# Losses {'ner': 520379.16086424957}
# Losses {'ner': 519640.6847401979}
# Losses {'ner': 519152.7633394089}
# Losses {'ner': 519629.0115708376}
# Losses {'ner': 518161.38096552267}
# Losses {'ner': 521240.2300050084}
# Losses {'ner': 520143.8585652802}
# Losses {'ner': 520192.4597274668}
# Losses {'ner': 519398.3899238763}
# Losses {'ner': 520088.45109210606}
# Losses {'ner': 520198.1151971016}
# Losses {'ner': 519382.17323299334}
# Losses {'ner': 518327.87077232485}
# Losses {'ner': 520337.3625581096}
# Losses {'ner': 519037.91160448804}
# Losses {'ner': 519194.1300425655}
# Losses {'ner': 518413.07916045445}
# Losses {'ner': 519693.8619650703}
# Losses {'ner': 519062.98268786224}
# Losses {'ner': 519918.7610716319}
# Losses {'ner': 519988.3114013355}
# Losses {'ner': 518649.4464816896}
# Losses {'ner': 519924.07629297953}
# Losses {'ner': 518205.3259534058}
# Losses {'ner': 518091.8702459261}
# Losses {'ner': 519306.36030356144}
# Losses {'ner': 518842.8185964501}
# Losses {'ner': 519241.2985177762}
# Losses {'ner': 519175.78933911305}
# Losses {'ner': 520549.23189720244}
# Losses {'ner': 518653.3412188131}
# Losses {'ner': 518318.61760277953}
# Losses {'ner': 519507.54817082244}
# Losses {'ner': 518493.1250444304}
# Losses {'ner': 518523.4662728559}
# Losses {'ner': 521559.6229179576}
# Losses {'ner': 518348.0878266038}
# Losses {'ner': 519434.76503057557}
# Losses {'ner': 518610.12894618884}
# Losses {'ner': 518478.0516203854}
# Losses {'ner': 518845.14980351547}
# Losses {'ner': 519103.90902612166}
# Losses {'ner': 518527.0378131764}
# Losses {'ner': 517846.03821324476}
# Losses {'ner': 519272.5436517815}
# Losses {'ner': 518909.71374178276}
# Saved model to final

# %% [markdown]
# ### Test the Model

# %%
test_text = 'Lucky is from Sri Lanka'
output_dir = 'final/'

print("Loading from", output_dir)

nlp2 = spacy.load(output_dir)
doc2 = nlp2(test_text)
for ent in doc2.ents:
    print(ent.label_, ent.text)
# Out:
# Loading from final/
# B-per Lucky
# B-geo Sri
# I-geo Lanka

# %% [markdown]
# Refer: https://spacy.io/usage/training#tips
